# %% [markdown]
# # Example Notebook

# %%
from snowflake.snowpark_connect import init_spark_session
from pyspark.sql.functions import col, lit, upper, concat

# Create Spark session
print("Initializing Spark session...")
spark = init_spark_session() # use connection_parameters={'connection_name': 'my_connection_name'} if you have a named connection in your config file
# Out:
# 2026-04-07 17:08:23,698 - snowflake_connect_server - INFO - [Thread 8427477184] - JAVA_HOME=/Users/jfreeberg/.jdk/jdk-21.0.8(1)/jdk-21.0.8+9/Contents/Home
# Initializing Spark session...
# 2026-04-07 17:08:25,218 - snowflake_connect_server - INFO - [Thread 12975796224] - Configuring session <snowflake.snowpark.session.Session: account="dexqa6", role="ACCOUNTADMIN", database="JASONFREEBERG", schema="PUBLIC", warehouse="DEX_WH">
# 2026-04-07 17:08:25,218 - snowflake_connect_server - INFO - [Thread 12975796224] - Telemetry initialized with <class 'snowflake.snowpark_connect.utils.telemetry.ClientTelemetrySink'>
# You might have more than one threads sharing the Session object trying to update eliminate_numeric_sql_value_cast_enabled. Updating this while other tasks are running can potentially cause unexpected behavior. Please update the session configuration before starting the threads.
# You might have more than one threads sharing the Session object trying to update cte_optimization_enabled. Updating this while other tasks are running can potentially cause unexpected behavior. Please update the session configuration before starting the threads.
# 2026-04-07 17:08:25,219 - snowflake_connect_server - INFO - [Thread 12975796224] - CTE optimization enabled: False
# 2026-04-07 17:08:26,549 - snowflake_connect_server - INFO - [Thread 12975796224] - Initialized SQL Parser Init in 0.98s
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 2026-04-07 17:08:26,842 - snowflake_connect_server - INFO - [Thread 12975796224] - Initialized SQL Parser Warm Up in 0.29s
# 2026-04-07 17:08:27,044 - snowflake_connect_server - INFO - [Thread 12975796224] - Initialized Initialize Session Stage in 0.20s
# 2026-04-07 17:08:27,191 - snowflake_connect_server - INFO - [Thread 12975796224] - Initialized Initialize Session Catalog in 0.15s
# 2026-04-07 17:08:27,688 - snowflake_connect_server - INFO - [Thread 12975796224] - Initialized Snowflake Connection Warm Up in 0.50s
# 2026-04-07 17:08:27,688 - snowflake_connect_server - INFO - [Thread 12975796224] - All resources initialized in 2.12s
# 2026-04-07 17:08:27,692 - snowflake_connect_server - INFO - [Thread 12975796224] - Starting Snowpark Connect server on unix:/var/folders/k3/8s2x432506zbzhtlq9pz_59c0000gn/T/tmpv4wde8pt/snowflake_sas_grpc.sock...
# 2026-04-07 17:08:27,693 - snowflake_connect_server - INFO - [Thread 12975796224] - Snowpark Connect server started!
